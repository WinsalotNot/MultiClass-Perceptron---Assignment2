# %% [markdown]
# <a href="https://colab.research.google.com/github/WinsalotNot/MultiClass-Perceptron---Assignment2/blob/main/Assignment_2_Multiclass_Perceptron_Andrew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTS**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **DATA ORGANIZATION**

# %%
# Stores data in data_file (does not include header!)
data_file = pd.read_csv('https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv')
print(data_file)

# Get the unqiue values in variety for classification
unique_variety = data_file['variety'].unique()
print(unique_variety)

# Take 80% of the dataset RANDOMLY as training data, random_state is the random seed used to ensure reproducibility
training_data_80 = data_file.sample(frac=0.8, random_state=45)
# Take 20% of the dataset by ELIMINATING the training data
testing_data_20 = data_file.drop(training_data_80.index)
print(f'Training Data 1: {(len(training_data_80)/len(data_file)*100)}% Testing Data 1: {(len(testing_data_20)/len(data_file)*100)}%')

# Take 70% of the dataset RANDOMLY as training data, random_state is the random seed used to ensure reproducibility
training_data_70 = data_file.sample(frac=0.7, random_state=24)
# Take 30% of the dataset by ELIMINATING the training data
testing_data_30 = data_file.drop(training_data_70.index)
print(f'Training Data 2: {(len(training_data_70)/len(data_file)*100)}% Testing Data 2: {(len(testing_data_30)/len(data_file)*100)}%')

# Take 60% of the dataset RANDOMLY as training data, random_state is the random seed used to ensure reproducibility
training_data_60 = data_file.sample(frac=0.6, random_state=23)
# Take 40% of the dataset by ELIMINATING the training data
testing_data_40 = data_file.drop(training_data_60.index)
print(f'Training Data 3: {(len(training_data_60)/len(data_file)*100)}% Testing Data 3: {(len(testing_data_40)/len(data_file)*100)}%')
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]
# ['Setosa' 'Versicolor' 'Virginica']
# Training Data 1: 80.0% Testing Data 1: 20.0%
# Training Data 2: 70.0% Testing Data 2: 30.0%
# Training Data 3: 60.0% Testing Data 3: 40.0%

# %% [markdown]
# # **MULTICLASS PERCEPTRON ALGORITHM**

# %%
def multiclass_perceptron(data, weight_2D_array, learning_rate, epoch):
  # Takes all row and all except last [:, :-1], then converts to numpy compatible array
  data_numpy = data.iloc[:, :-1].to_numpy()

  # Normalize input using z-score standardization, where the mean is at 0
  data_numpy = (data_numpy - np.mean(data_numpy, axis=0)) / np.std(data_numpy, axis=0)

  # Add extra synthetic features: quadratic terms
  radius_feature = np.sqrt(data_numpy[:, 0]**2 + data_numpy[:, 1]**2).reshape(-1, 1)
  x_squared = (data_numpy[:, 0] ** 2).reshape(-1, 1)
  y_squared = (data_numpy[:, 1] ** 2).reshape(-1, 1)
  xy_interaction = (data_numpy[:, 0] * data_numpy[:, 1]).reshape(-1, 1)

  # Stack new features
  data_numpy = np.hstack((data_numpy, radius_feature, x_squared, y_squared, xy_interaction))

  # Add bias to allow the boundary line to shift left or right freely (as to not be forced to go through origin [0,0])
  # Uses np.hstack to append a column of ones/zeros to the 2D array. Note: .shape[0] is the number of rows, '1' is number of column
  data_numpy = np.hstack((data_numpy, np.ones((data_numpy.shape[0], 1))))
  weight_2D_array = np.hstack((weight_2D_array, np.zeros((weight_2D_array.shape[0], 5))))

  # Each unqiue data in 'variety' are represented sequentially from 0
  result_each_indexes = data.iloc[:, -1].to_numpy()                                         # Takes all rows and ONLY the last column [:, -1], then converts to numpy compatible array
  unique_labels, results_given_int = np.unique(result_each_indexes, return_inverse=True)    # Gets an array of the labels of each uniques and an array of the unique values mapped to their respective indexes
  label_to_index = {label: idx for idx, label in enumerate(unique_labels)}                  # Shows which unqiue values are assigned to which index
  print("Label Mapping:", label_to_index)
  print("Converted Indexes:", results_given_int)

  updated_weights = weight_2D_array.copy()
  best_weights = updated_weights.copy()
  best_accuracy = 0.0

  iteration = 0
  success = False
  while (iteration < epoch):
    weighted_sums = np.dot(data_numpy, updated_weights.T) # Uses dot matrix calculation as well as tansposing the updated_weights (turning the features into rows and classes in columns)
    results_calculated = np.argmax(weighted_sums, axis=1) # Because classes are now rows, take the biggest one from each row

    correct_predictions = np.sum(results_calculated == results_given_int)
    accuracy = correct_predictions / len(data_numpy)  # Compute accuracy

    # Track best accuracy and corresponding weights
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_weights = updated_weights.copy()

    print(f'Epoch {iteration + 1}: {correct_predictions}/{len(data_numpy)} samples correctly classified.')

    if correct_predictions == len(data_numpy):  # If 100% correct, terminate early
        print(f'Converged at epoch {iteration + 1}')
        success = True
        break

    for index, (result_calculated, result_given_int) in enumerate(zip(results_calculated, results_given_int)):
      if result_calculated != result_given_int:
          updated_weights[result_given_int] += learning_rate * data_numpy[index]  # Increases the expected class
          updated_weights[result_calculated] -= learning_rate * data_numpy[index] # Decreases the predicted class

    iteration += 1

  print(f'Best accuracy: {best_accuracy * 100:.2f}%')
  print(f'Best weights:\n{best_weights}')

  if not success:
    print(f'Given {epoch} epoch, weights did not converge: {updated_weights}')

weight_2D_array = np.array([
    [0.1, 0.2, 0.3, -0.1],
    [0.5, 0.4, 0.3, -0.2],
    [0.6, 0.2, -0.4, 0.3]
])
# After Transposing:
# [
#   [0.1, 0.5, 0.6]
#   [0.2, 0.4, 0.2]
#   [0.3, 0.3, -0.4]
#   [-0.1, -0.2, 0.3]
# ]

multiclass_perceptron(training_data_80, weight_2D_array, 0.001, 10000)
# Out:
# Label Mapping: {'Setosa': 0, 'Versicolor': 1, 'Virginica': 2}
# Converted Indexes: [0 0 2 0 0 0 0 2 2 2 0 2 2 2 2 0 2 2 0 1 1 1 2 1 0 2 1 1 0 1 1 1 2 2 0 2 0
#  0 1 0 0 1 0 1 1 0 2 1 2 0 0 1 2 0 2 0 0 1 0 1 1 2 1 2 0 0 0 0 1 0 1 2 1 1
#  1 0 0 1 0 1 2 2 2 1 1 2 1 0 1 1 1 2 1 1 2 1 1 2 2 2 0 0 1 2 2 2 0 1 2 1 1
#  1 0 2 2 0 0 2 0 2]
# Epoch 1: 52/120 samples correctly classified.
# Epoch 2: 75/120 samples correctly classified.
# Epoch 3: 87/120 samples correctly classified.
# Epoch 4: 81/120 samples correctly classified.
# Epoch 5: 93/120 samples correctly classified.
# Epoch 6: 93/120 samples correctly classified.
# Epoch 7: 94/120 samples correctly classified.
# Epoch 8: 95/120 samples correctly classified.
# Epoch 9: 97/120 samples correctly classified.
# Epoch 10: 97/120 samples correctly classified.
# Epoch 11: 99/120 samples correctly classified.
# Epoch 12: 97/120 samples correctly classified.
# Epoch 13: 99/120 samples correctly classified.
# Epoch 14: 99/120 samples correctly classified.
# Epoch 15: 98/120 samples correctly classified.
# Epoch 16: 102/120 samples correctly classified.
# Epoch 17: 100/120 samples correctly classified.
# Epoch 18: 101/120 samples correctly classified.
# Epoch 19: 99/120 samples correctly classified.
# Epoch 20: 104/120 samples correctly classified.
# Epoch 21: 99/120 samples correctly classified.
# Epoch 22: 105/120 samples correctly classified.
# Epoch 23: 105/120 samples correctly classified.
# Epoch 24: 106/120 samples correctly classified.
# Epoch 25: 101/120 samples correctly classified.
# Epoch 26: 105/120 samples correctly classified.
# Epoch 27: 105/120 samples correctly classified.
# Epoch 28: 107/120 samples correctly classified.
# Epoch 29: 106/120 samples correctly classified.
# Epoch 30: 108/120 samples correctly classified.
# Epoch 31: 107/120 samples correctly classified.
# Epoch 32: 108/120 samples correctly classified.
# Epoch 33: 108/120 samples correctly classified.
# Epoch 34: 108/120 samples correctly classified.
# Epoch 35: 107/120 samples correctly classified.
# Epoch 36: 105/120 samples correctly classified.
# Epoch 37: 106/120 samples correctly classified.
# Epoch 38: 107/120 samples correctly classified.
# Epoch 39: 107/120 samples correctly classified.
# Epoch 40: 108/120 samples correctly classified.
# Epoch 41: 109/120 samples correctly classified.
# Epoch 42: 108/120 samples correctly classified.
# Epoch 43: 109/120 samples correctly classified.
# Epoch 44: 108/120 samples correctly classified.
# Epoch 45: 108/120 samples correctly classified.
# Epoch 46: 107/120 samples correctly classified.
# Epoch 47: 105/120 samples correctly classified.
# Epoch 48: 108/120 samples correctly classified.
# Epoch 49: 110/120 samples correctly classified.
# Epoch 50: 108/120 samples correctly classified.
# Epoch 51: 109/120 samples correctly classified.
# Epoch 52: 110/120 samples correctly classified.
# Epoch 53: 111/120 samples correctly classified.
# Epoch 54: 110/120 samples correctly classified.
# Epoch 55: 111/120 samples correctly classified.
# Epoch 56: 110/120 samples correctly classified.
# Epoch 57: 112/120 samples correctly classified.
# Epoch 58: 111/120 samples correctly classified.
# Epoch 59: 112/120 samples correctly classified.
# Epoch 60: 110/120 samples correctly classified.
# Epoch 61: 111/120 samples correctly classified.
# Epoch 62: 111/120 samples correctly classified.
# Epoch 63: 110/120 samples correctly classified.
# Epoch 64: 110/120 samples correctly classified.
# Epoch 65: 110/120 samples correctly classified.
# Epoch 66: 110/120 samples correctly classified.
# Epoch 67: 110/120 samples correctly classified.
# Epoch 68: 110/120 samples correctly classified.
# Epoch 69: 112/120 samples correctly classified.
# Epoch 70: 112/120 samples correctly classified.
# Epoch 71: 112/120 samples correctly classified.
# Epoch 72: 112/120 samples correctly classified.
# Epoch 73: 112/120 samples correctly classified.
# Epoch 74: 111/120 samples correctly classified.
# Epoch 75: 112/120 samples correctly classified.
# Epoch 76: 112/120 samples correctly classified.
# Epoch 77: 112/120 samples correctly classified.
# Epoch 78: 112/120 samples correctly classified.
# Epoch 79: 113/120 samples correctly classified.
# Epoch 80: 112/120 samples correctly classified.
# Epoch 81: 113/120 samples correctly classified.
# Epoch 82: 113/120 samples correctly classified.
# Epoch 83: 114/120 samples correctly classified.
# Epoch 84: 113/120 samples correctly classified.
# Epoch 85: 113/120 samples correctly classified.
# Epoch 86: 113/120 samples correctly classified.
# Epoch 87: 113/120 samples correctly classified.
# Epoch 88: 112/120 samples correctly classified.
# Epoch 89: 112/120 samples correctly classified.
# Epoch 90: 112/120 samples correctly classified.
# Epoch 91: 112/120 samples correctly classified.
# Epoch 92: 112/120 samples correctly classified.
# Epoch 93: 113/120 samples correctly classified.
# Epoch 94: 112/120 samples correctly classified.
# Epoch 95: 113/120 samples correctly classified.
# Epoch 96: 112/120 samples correctly classified.
# Epoch 97: 113/120 samples correctly classified.
# Epoch 98: 113/120 samples correctly classified.
# Epoch 99: 113/120 samples correctly classified.
# Epoch 100: 113/120 samples correctly classified.
# Epoch 101: 113/120 samples correctly classified.
# Epoch 102: 113/120 samples correctly classified.
# Epoch 103: 113/120 samples correctly classified.
# Epoch 104: 113/120 samples correctly classified.
# Epoch 105: 114/120 samples correctly classified.
# Epoch 106: 113/120 samples correctly classified.
# Epoch 107: 113/120 samples correctly classified.
# Epoch 108: 114/120 samples correctly classified.
# Epoch 109: 112/120 samples correctly classified.
# Epoch 110: 113/120 samples correctly classified.
# Epoch 111: 113/120 samples correctly classified.
# Epoch 112: 112/120 samples correctly classified.
# Epoch 113: 113/120 samples correctly classified.
# Epoch 114: 112/120 samples correctly classified.
# Epoch 115: 112/120 samples correctly classified.
# Epoch 116: 112/120 samples correctly classified.
# Epoch 117: 110/120 samples correctly classified.
# Epoch 118: 114/120 samples correctly classified.
# Epoch 119: 114/120 samples correctly classified.
# Epoch 120: 113/120 samples correctly classified.
# Epoch 121: 114/120 samples correctly classified.
# Epoch 122: 115/120 samples correctly classified.
# Epoch 123: 114/120 samples correctly classified.
# Epoch 124: 114/120 samples correctly classified.
# Epoch 125: 115/120 samples correctly classified.
# Epoch 126: 114/120 samples correctly classified.
# Epoch 127: 114/120 samples correctly classified.
# Epoch 128: 114/120 samples correctly classified.
# Epoch 129: 115/120 samples correctly classified.
# Epoch 130: 115/120 samples correctly classified.
# Epoch 131: 114/120 samples correctly classified.
# Epoch 132: 115/120 samples correctly classified.
# Epoch 133: 115/120 samples correctly classified.
# Epoch 134: 114/120 samples correctly classified.
# Epoch 135: 115/120 samples correctly classified.
# Epoch 136: 115/120 samples correctly classified.
# Epoch 137: 114/120 samples correctly classified.
# Epoch 138: 114/120 samples correctly classified.
# Epoch 139: 114/120 samples correctly classified.
# Epoch 140: 115/120 samples correctly classified.
# Epoch 141: 113/120 samples correctly classified.
# Epoch 142: 115/120 samples correctly classified.
# Epoch 143: 114/120 samples correctly classified.
# Epoch 144: 114/120 samples correctly classified.
# Epoch 145: 115/120 samples correctly classified.
# Epoch 146: 115/120 samples correctly classified.
# Epoch 147: 114/120 samples correctly classified.
# Epoch 148: 114/120 samples correctly classified.
# Epoch 149: 115/120 samples correctly classified.
# Epoch 150: 115/120 samples correctly classified.
# Epoch 151: 113/120 samples correctly classified.
# Epoch 152: 116/120 samples correctly classified.
# Epoch 153: 114/120 samples correctly classified.
# Epoch 154: 115/120 samples correctly classified.
# Epoch 155: 115/120 samples correctly classified.
# Epoch 156: 116/120 samples correctly classified.
# Epoch 157: 114/120 samples correctly classified.
# Epoch 158: 115/120 samples correctly classified.
# Epoch 159: 115/120 samples correctly classified.
# Epoch 160: 116/120 samples correctly classified.
# Epoch 161: 114/120 samples correctly classified.
# Epoch 162: 117/120 samples correctly classified.
# Epoch 163: 115/120 samples correctly classified.
# Epoch 164: 115/120 samples correctly classified.
# Epoch 165: 115/120 samples correctly classified.
# Epoch 166: 116/120 samples correctly classified.
# Epoch 167: 114/120 samples correctly classified.
# Epoch 168: 116/120 samples correctly classified.
# Epoch 169: 114/120 samples correctly classified.
# Epoch 170: 115/120 samples correctly classified.
# Epoch 171: 114/120 samples correctly classified.
# Epoch 172: 116/120 samples correctly classified.
# Epoch 173: 114/120 samples correctly classified.
# Epoch 174: 116/120 samples correctly classified.
# Epoch 175: 114/120 samples correctly classified.
# Epoch 176: 116/120 samples correctly classified.
# Epoch 177: 114/120 samples correctly classified.
# Epoch 178: 116/120 samples correctly classified.
# Epoch 179: 113/120 samples correctly classified.
# Epoch 180: 114/120 samples correctly classified.
# Epoch 181: 113/120 samples correctly classified.
# Epoch 182: 115/120 samples correctly classified.
# Epoch 183: 114/120 samples correctly classified.
# Epoch 184: 116/120 samples correctly classified.
# Epoch 185: 116/120 samples correctly classified.
# Epoch 186: 114/120 samples correctly classified.
# Epoch 187: 115/120 samples correctly classified.
# Epoch 188: 114/120 samples correctly classified.
# Epoch 189: 116/120 samples correctly classified.
# Epoch 190: 114/120 samples correctly classified.
# Epoch 191: 116/120 samples correctly classified.
# Epoch 192: 114/120 samples correctly classified.
# Epoch 193: 116/120 samples correctly classified.
# Epoch 194: 114/120 samples correctly classified.
# Epoch 195: 117/120 samples correctly classified.
# Epoch 196: 115/120 samples correctly classified.
# Epoch 197: 116/120 samples correctly classified.
# Epoch 198: 114/120 samples correctly classified.
# Epoch 199: 115/120 samples correctly classified.
# Epoch 200: 115/120 samples correctly classified.
# Epoch 201: 115/120 samples correctly classified.
# Epoch 202: 116/120 samples correctly classified.
# Epoch 203: 115/120 samples correctly classified.
# Epoch 204: 115/120 samples correctly classified.
# Epoch 205: 116/120 samples correctly classified.
# Epoch 206: 115/120 samples correctly classified.
# Epoch 207: 115/120 samples correctly classified.
# Epoch 208: 116/120 samples correctly classified.
# Epoch 209: 115/120 samples correctly classified.
# Epoch 210: 115/120 samples correctly classified.
# Epoch 211: 116/120 samples correctly classified.
# Epoch 212: 115/120 samples correctly classified.
# Epoch 213: 115/120 samples correctly classified.
# Epoch 214: 116/120 samples correctly classified.
# Epoch 215: 115/120 samples correctly classified.
# Epoch 216: 115/120 samples correctly classified.
# Epoch 217: 116/120 samples correctly classified.
# Epoch 218: 115/120 samples correctly classified.
# Epoch 219: 115/120 samples correctly classified.
# Epoch 220: 116/120 samples correctly classified.
# Epoch 221: 115/120 samples correctly classified.
# Epoch 222: 115/120 samples correctly classified.
# Epoch 223: 116/120 samples correctly classified.
# Epoch 224: 115/120 samples correctly classified.
# Epoch 225: 115/120 samples correctly classified.
# Epoch 226: 115/120 samples correctly classified.
# Epoch 227: 115/120 samples correctly classified.
# Epoch 228: 115/120 samples correctly classified.
# Epoch 229: 115/120 samples correctly classified.
# Epoch 230: 115/120 samples correctly classified.
# Epoch 231: 115/120 samples correctly classified.
# Epoch 232: 115/120 samples correctly classified.
# Epoch 233: 116/120 samples correctly classified.
# Epoch 234: 114/120 samples correctly classified.
# Epoch 235: 115/120 samples correctly classified.
# Epoch 236: 116/120 samples correctly classified.
# Epoch 237: 115/120 samples correctly classified.
# Epoch 238: 115/120 samples correctly classified.
# Epoch 239: 115/120 samples correctly classified.
# Epoch 240: 113/120 samples correctly classified.
# Epoch 241: 115/120 samples correctly classified.
# Epoch 242: 115/120 samples correctly classified.
# Epoch 243: 116/120 samples correctly classified.
# Epoch 244: 115/120 samples correctly classified.
# Epoch 245: 115/120 samples correctly classified.
# Epoch 246: 115/120 samples correctly classified.
# Epoch 247: 115/120 samples correctly classified.
# Epoch 248: 115/120 samples correctly classified.
# Epoch 249: 115/120 samples correctly classified.
# Epoch 250: 116/120 samples correctly classified.
# Epoch 251: 115/120 samples correctly classified.
# Epoch 252: 114/120 samples correctly classified.
# Epoch 253: 115/120 samples correctly classified.
# Epoch 254: 116/120 samples correctly classified.
# Epoch 255: 115/120 samples correctly classified.
# Epoch 256: 114/120 samples correctly classified.
# Epoch 257: 115/120 samples correctly classified.
# Epoch 258: 116/120 samples correctly classified.
# Epoch 259: 115/120 samples correctly classified.
# Epoch 260: 115/120 samples correctly classified.
# Epoch 261: 115/120 samples correctly classified.
# Epoch 262: 115/120 samples correctly classified.
# Epoch 263: 115/120 samples correctly classified.
# Epoch 264: 116/120 samples correctly classified.
# Epoch 265: 115/120 samples correctly classified.
# Epoch 266: 115/120 samples correctly classified.
# Epoch 267: 115/120 samples correctly classified.
# Epoch 268: 113/120 samples correctly classified.
# Epoch 269: 114/120 samples correctly classified.
# Epoch 270: 115/120 samples correctly classified.
# Epoch 271: 114/120 samples correctly classified.
# Epoch 272: 115/120 samples correctly classified.
# Epoch 273: 114/120 samples correctly classified.
# Epoch 274: 115/120 samples correctly classified.
# Epoch 275: 116/120 samples correctly classified.
# Epoch 276: 115/120 samples correctly classified.
# Epoch 277: 114/120 samples correctly classified.
# Epoch 278: 115/120 samples correctly classified.
# Epoch 279: 116/120 samples correctly classified.
# Epoch 280: 115/120 samples correctly classified.
# Epoch 281: 114/120 samples correctly classified.
# Epoch 282: 115/120 samples correctly classified.
# Epoch 283: 116/120 samples correctly classified.
# Epoch 284: 115/120 samples correctly classified.
# Epoch 285: 114/120 samples correctly classified.
# Epoch 286: 115/120 samples correctly classified.
# Epoch 287: 116/120 samples correctly classified.
# Epoch 288: 115/120 samples correctly classified.
# Epoch 289: 113/120 samples correctly classified.
# Epoch 290: 115/120 samples correctly classified.
# Epoch 291: 115/120 samples correctly classified.
# Epoch 292: 115/120 samples correctly classified.
# Epoch 293: 114/120 samples correctly classified.
# Epoch 294: 115/120 samples correctly classified.
# Epoch 295: 115/120 samples correctly classified.
# Epoch 296: 115/120 samples correctly classified.
# Epoch 297: 115/120 samples correctly classified.
# Epoch 298: 116/120 samples correctly classified.
# Epoch 299: 114/120 samples correctly classified.
# Epoch 300: 115/120 samples correctly classified.
# Epoch 301: 112/120 samples correctly classified.
# Epoch 302: 114/120 samples correctly classified.
# Epoch 303: 114/120 samples correctly classified.
# Epoch 304: 115/120 samples correctly classified.
# Epoch 305: 114/120 samples correctly classified.
# Epoch 306: 115/120 samples correctly classified.
# Epoch 307: 115/120 samples correctly classified.
# Epoch 308: 114/120 samples correctly classified.
# Epoch 309: 115/120 samples correctly classified.
# Epoch 310: 115/120 samples correctly classified.
# Epoch 311: 115/120 samples correctly classified.
# Epoch 312: 115/120 samples correctly classified.
# Epoch 313: 113/120 samples correctly classified.
# Epoch 314: 115/120 samples correctly classified.
# Epoch 315: 116/120 samples correctly classified.
# Epoch 316: 114/120 samples correctly classified.
# Epoch 317: 115/120 samples correctly classified.
# Epoch 318: 114/120 samples correctly classified.
# Epoch 319: 115/120 samples correctly classified.
# Epoch 320: 116/120 samples correctly classified.
# Epoch 321: 115/120 samples correctly classified.
# Epoch 322: 115/120 samples correctly classified.
# Epoch 323: 115/120 samples correctly classified.
# Epoch 324: 115/120 samples correctly classified.
# Epoch 325: 116/120 samples correctly classified.
# Epoch 326: 116/120 samples correctly classified.
# Epoch 327: 116/120 samples correctly classified.
# Epoch 328: 115/120 samples correctly classified.
# Epoch 329: 115/120 samples correctly classified.
# Epoch 330: 115/120 samples correctly classified.
# Epoch 331: 115/120 samples correctly classified.
# Epoch 332: 116/120 samples correctly classified.
# Epoch 333: 116/120 samples correctly classified.
# Epoch 334: 114/120 samples correctly classified.
# Epoch 335: 115/120 samples correctly classified.
# Epoch 336: 115/120 samples correctly classified.
# Epoch 337: 115/120 samples correctly classified.
# Epoch 338: 115/120 samples correctly classified.
# Epoch 339: 116/120 samples correctly classified.
# Epoch 340: 116/120 samples correctly classified.
# Epoch 341: 115/120 samples correctly classified.
# Epoch 342: 114/120 samples correctly classified.
# Epoch 343: 114/120 samples correctly classified.
# Epoch 344: 115/120 samples correctly classified.
# Epoch 345: 115/120 samples correctly classified.
# Epoch 346: 116/120 samples correctly classified.
# Epoch 347: 116/120 samples correctly classified.
# Epoch 348: 115/120 samples correctly classified.
# Epoch 349: 116/120 samples correctly classified.
# Epoch 350: 116/120 samples correctly classified.
# Epoch 351: 117/120 samples correctly classified.
# Epoch 352: 115/120 samples correctly classified.
# Epoch 353: 116/120 samples correctly classified.
# Epoch 354: 115/120 samples correctly classified.
# Epoch 355: 115/120 samples correctly classified.
# Epoch 356: 117/120 samples correctly classified.
# Epoch 357: 115/120 samples correctly classified.
# Epoch 358: 117/120 samples correctly classified.
# Epoch 359: 115/120 samples correctly classified.
# Epoch 360: 117/120 samples correctly classified.
# Epoch 361: 115/120 samples correctly classified.
# Epoch 362: 116/120 samples correctly classified.
# Epoch 363: 115/120 samples correctly classified.
# Epoch 364: 115/120 samples correctly classified.
# Epoch 365: 117/120 samples correctly classified.
# Epoch 366: 115/120 samples correctly classified.
# Epoch 367: 117/120 samples correctly classified.
# Epoch 368: 115/120 samples correctly classified.
# Epoch 369: 116/120 samples correctly classified.
# Epoch 370: 115/120 samples correctly classified.
# Epoch 371: 115/120 samples correctly classified.
# Epoch 372: 117/120 samples correctly classified.
# Epoch 373: 115/120 samples correctly classified.
# Epoch 374: 116/120 samples correctly classified.
# Epoch 375: 115/120 samples correctly classified.
# Epoch 376: 116/120 samples correctly classified.
# Epoch 377: 115/120 samples correctly classified.
# Epoch 378: 115/120 samples correctly classified.
# Epoch 379: 117/120 samples correctly classified.
# Epoch 380: 115/120 samples correctly classified.
# Epoch 381: 117/120 samples correctly classified.
# Epoch 382: 116/120 samples correctly classified.
# Epoch 383: 117/120 samples correctly classified.
# Epoch 384: 115/120 samples correctly classified.
# Epoch 385: 117/120 samples correctly classified.
# Epoch 386: 115/120 samples correctly classified.
# Epoch 387: 116/120 samples correctly classified.
# Epoch 388: 114/120 samples correctly classified.
# Epoch 389: 115/120 samples correctly classified.
# Epoch 390: 115/120 samples correctly classified.
# Epoch 391: 116/120 samples correctly classified.
# Epoch 392: 115/120 samples correctly classified.
# Epoch 393: 117/120 samples correctly classified.
# Epoch 394: 117/120 samples correctly classified.
# Epoch 395: 115/120 samples correctly classified.
# Epoch 396: 117/120 samples correctly classified.
# Epoch 397: 115/120 samples correctly classified.
# Epoch 398: 117/120 samples correctly classified.
# Epoch 399: 115/120 samples correctly classified.
# Epoch 400: 117/120 samples correctly classified.
# Epoch 401: 115/120 samples correctly classified.
# Epoch 402: 117/120 samples correctly classified.
# Epoch 403: 116/120 samples correctly classified.
# Epoch 404: 116/120 samples correctly classified.
# Epoch 405: 117/120 samples correctly classified.
# Epoch 406: 115/120 samples correctly classified.
# Epoch 407: 117/120 samples correctly classified.
# Epoch 408: 115/120 samples correctly classified.
# Epoch 409: 117/120 samples correctly classified.
# Epoch 410: 116/120 samples correctly classified.
# Epoch 411: 116/120 samples correctly classified.
# Epoch 412: 117/120 samples correctly classified.
# Epoch 413: 115/120 samples correctly classified.
# Epoch 414: 117/120 samples correctly classified.
# Epoch 415: 115/120 samples correctly classified.
# Epoch 416: 116/120 samples correctly classified.
# Epoch 417: 117/120 samples correctly classified.
# Epoch 418: 116/120 samples correctly classified.
# Epoch 419: 116/120 samples correctly classified.
# Epoch 420: 116/120 samples correctly classified.
# Epoch 421: 117/120 samples correctly classified.
# Epoch 422: 115/120 samples correctly classified.
# Epoch 423: 117/120 samples correctly classified.
# Epoch 424: 115/120 samples correctly classified.
# Epoch 425: 117/120 samples correctly classified.
# Epoch 426: 115/120 samples correctly classified.
# Epoch 427: 117/120 samples correctly classified.
# Epoch 428: 116/120 samples correctly classified.
# Epoch 429: 116/120 samples correctly classified.
# Epoch 430: 117/120 samples correctly classified.
# Epoch 431: 116/120 samples correctly classified.
# Epoch 432: 116/120 samples correctly classified.
# Epoch 433: 116/120 samples correctly classified.
# Epoch 434: 117/120 samples correctly classified.
# Epoch 435: 117/120 samples correctly classified.
# Epoch 436: 117/120 samples correctly classified.
# Epoch 437: 116/120 samples correctly classified.
# Epoch 438: 117/120 samples correctly classified.
# Epoch 439: 116/120 samples correctly classified.
# Epoch 440: 116/120 samples correctly classified.
# Epoch 441: 116/120 samples correctly classified.
# Epoch 442: 117/120 samples correctly classified.
# Epoch 443: 117/120 samples correctly classified.
# Epoch 444: 117/120 samples correctly classified.
# Epoch 445: 116/120 samples correctly classified.
# Epoch 446: 117/120 samples correctly classified.
# Epoch 447: 116/120 samples correctly classified.
# Epoch 448: 116/120 samples correctly classified.
# Epoch 449: 116/120 samples correctly classified.
# Epoch 450: 117/120 samples correctly classified.
# Epoch 451: 117/120 samples correctly classified.
# Epoch 452: 117/120 samples correctly classified.
# Epoch 453: 117/120 samples correctly classified.
# Epoch 454: 116/120 samples correctly classified.
# Epoch 455: 116/120 samples correctly classified.
# Epoch 456: 117/120 samples correctly classified.
# Epoch 457: 117/120 samples correctly classified.
# Epoch 458: 117/120 samples correctly classified.
# Epoch 459: 117/120 samples correctly classified.
# Epoch 460: 116/120 samples correctly classified.
# Epoch 461: 116/120 samples correctly classified.
# Epoch 462: 117/120 samples correctly classified.
# Epoch 463: 117/120 samples correctly classified.
# Epoch 464: 117/120 samples correctly classified.
# Epoch 465: 117/120 samples correctly classified.
# Epoch 466: 117/120 samples correctly classified.
# Epoch 467: 118/120 samples correctly classified.
# Epoch 468: 118/120 samples correctly classified.
# Epoch 469: 118/120 samples correctly classified.
# Epoch 470: 117/120 samples correctly classified.
# Epoch 471: 116/120 samples correctly classified.
# Epoch 472: 116/120 samples correctly classified.
# Epoch 473: 117/120 samples correctly classified.
# Epoch 474: 117/120 samples correctly classified.
# Epoch 475: 118/120 samples correctly classified.
# Epoch 476: 118/120 samples correctly classified.
# Epoch 477: 117/120 samples correctly classified.
# Epoch 478: 116/120 samples correctly classified.
# Epoch 479: 116/120 samples correctly classified.
# Epoch 480: 117/120 samples correctly classified.
# Epoch 481: 117/120 samples correctly classified.
# Epoch 482: 116/120 samples correctly classified.
# Epoch 483: 116/120 samples correctly classified.
# Epoch 484: 118/120 samples correctly classified.
# Epoch 485: 118/120 samples correctly classified.
# Epoch 486: 117/120 samples correctly classified.
# Epoch 487: 117/120 samples correctly classified.
# Epoch 488: 117/120 samples correctly classified.
# Epoch 489: 117/120 samples correctly classified.
# Epoch 490: 116/120 samples correctly classified.
# Epoch 491: 116/120 samples correctly classified.
# Epoch 492: 118/120 samples correctly classified.
# Epoch 493: 118/120 samples correctly classified.
# Epoch 494: 117/120 samples correctly classified.
# Epoch 495: 117/120 samples correctly classified.
# Epoch 496: 117/120 samples correctly classified.
# Epoch 497: 117/120 samples correctly classified.
# Epoch 498: 116/120 samples correctly classified.
# Epoch 499: 117/120 samples correctly classified.
# Epoch 500: 117/120 samples correctly classified.
# Epoch 501: 117/120 samples correctly classified.
# Epoch 502: 116/120 samples correctly classified.
# Epoch 503: 116/120 samples correctly classified.
# Epoch 504: 118/120 samples correctly classified.
# Epoch 505: 117/120 samples correctly classified.
# Epoch 506: 117/120 samples correctly classified.
# Epoch 507: 117/120 samples correctly classified.
# Epoch 508: 117/120 samples correctly classified.
# Epoch 509: 116/120 samples correctly classified.
# Epoch 510: 116/120 samples correctly classified.
# Epoch 511: 118/120 samples correctly classified.
# Epoch 512: 118/120 samples correctly classified.
# Epoch 513: 117/120 samples correctly classified.
# Epoch 514: 117/120 samples correctly classified.
# Epoch 515: 117/120 samples correctly classified.
# Epoch 516: 117/120 samples correctly classified.
# Epoch 517: 116/120 samples correctly classified.
# Epoch 518: 116/120 samples correctly classified.
# Epoch 519: 118/120 samples correctly classified.
# Epoch 520: 118/120 samples correctly classified.
# Epoch 521: 117/120 samples correctly classified.
# Epoch 522: 117/120 samples correctly classified.
# Epoch 523: 116/120 samples correctly classified.
# Epoch 524: 117/120 samples correctly classified.
# Epoch 525: 117/120 samples correctly classified.
# Epoch 526: 117/120 samples correctly classified.
# Epoch 527: 117/120 samples correctly classified.
# Epoch 528: 118/120 samples correctly classified.
# Epoch 529: 118/120 samples correctly classified.
# Epoch 530: 118/120 samples correctly classified.
# Epoch 531: 118/120 samples correctly classified.
# Epoch 532: 118/120 samples correctly classified.
# Epoch 533: 117/120 samples correctly classified.
# Epoch 534: 116/120 samples correctly classified.
# Epoch 535: 115/120 samples correctly classified.
# Epoch 536: 116/120 samples correctly classified.
# Epoch 537: 114/120 samples correctly classified.
# Epoch 538: 116/120 samples correctly classified.
# Epoch 539: 115/120 samples correctly classified.
# Epoch 540: 117/120 samples correctly classified.
# Epoch 541: 117/120 samples correctly classified.
# Epoch 542: 117/120 samples correctly classified.
# Epoch 543: 117/120 samples correctly classified.
# Epoch 544: 117/120 samples correctly classified.
# Epoch 545: 118/120 samples correctly classified.
# Epoch 546: 118/120 samples correctly classified.
# Epoch 547: 118/120 samples correctly classified.
# Epoch 548: 118/120 samples correctly classified.
# Epoch 549: 117/120 samples correctly classified.
# Epoch 550: 116/120 samples correctly classified.
# Epoch 551: 116/120 samples correctly classified.
# Epoch 552: 116/120 samples correctly classified.
# Epoch 553: 117/120 samples correctly classified.
# Epoch 554: 117/120 samples correctly classified.
# Epoch 555: 117/120 samples correctly classified.
# Epoch 556: 118/120 samples correctly classified.
# Epoch 557: 118/120 samples correctly classified.
# Epoch 558: 118/120 samples correctly classified.
# Epoch 559: 118/120 samples correctly classified.
# Epoch 560: 117/120 samples correctly classified.
# Epoch 561: 116/120 samples correctly classified.
# Epoch 562: 116/120 samples correctly classified.
# Epoch 563: 118/120 samples correctly classified.
# Epoch 564: 118/120 samples correctly classified.
# Epoch 565: 118/120 samples correctly classified.
# Epoch 566: 118/120 samples correctly classified.
# Epoch 567: 117/120 samples correctly classified.
# Epoch 568: 116/120 samples correctly classified.
# Epoch 569: 115/120 samples correctly classified.
# Epoch 570: 117/120 samples correctly classified.
# Epoch 571: 117/120 samples correctly classified.
# Epoch 572: 117/120 samples correctly classified.
# Epoch 573: 117/120 samples correctly classified.
# Epoch 574: 118/120 samples correctly classified.
# Epoch 575: 118/120 samples correctly classified.
# Epoch 576: 118/120 samples correctly classified.
# Epoch 577: 118/120 samples correctly classified.
# Epoch 578: 118/120 samples correctly classified.
# Epoch 579: 117/120 samples correctly classified.
# Epoch 580: 115/120 samples correctly classified.
# Epoch 581: 117/120 samples correctly classified.
# Epoch 582: 118/120 samples correctly classified.
# Epoch 583: 118/120 samples correctly classified.
# Epoch 584: 117/120 samples correctly classified.
# Epoch 585: 116/120 samples correctly classified.
# Epoch 586: 116/120 samples correctly classified.
# Epoch 587: 117/120 samples correctly classified.
# Epoch 588: 117/120 samples correctly classified.
# Epoch 589: 118/120 samples correctly classified.
# Epoch 590: 117/120 samples correctly classified.
# Epoch 591: 117/120 samples correctly classified.
# Epoch 592: 117/120 samples correctly classified.
# Epoch 593: 116/120 samples correctly classified.
# Epoch 594: 116/120 samples correctly classified.
# Epoch 595: 118/120 samples correctly classified.
# Epoch 596: 118/120 samples correctly classified.
# Epoch 597: 118/120 samples correctly classified.
# Epoch 598: 118/120 samples correctly classified.
# Epoch 599: 117/120 samples correctly classified.
# Epoch 600: 116/120 samples correctly classified.
# Epoch 601: 117/120 samples correctly classified.
# Epoch 602: 116/120 samples correctly classified.
# Epoch 603: 117/120 samples correctly classified.
# Epoch 604: 118/120 samples correctly classified.
# Epoch 605: 117/120 samples correctly classified.
# Epoch 606: 117/120 samples correctly classified.
# Epoch 607: 118/120 samples correctly classified.
# Epoch 608: 118/120 samples correctly classified.
# Epoch 609: 117/120 samples correctly classified.
# Epoch 610: 117/120 samples correctly classified.
# Epoch 611: 118/120 samples correctly classified.
# Epoch 612: 117/120 samples correctly classified.
# Epoch 613: 117/120 samples correctly classified.
# Epoch 614: 117/120 samples correctly classified.
# Epoch 615: 117/120 samples correctly classified.
# Epoch 616: 117/120 samples correctly classified.
# Epoch 617: 118/120 samples correctly classified.
# Epoch 618: 118/120 samples correctly classified.
# Epoch 619: 118/120 samples correctly classified.
# Epoch 620: 118/120 samples correctly classified.
# Epoch 621: 118/120 samples correctly classified.
# Epoch 622: 118/120 samples correctly classified.
# Epoch 623: 118/120 samples correctly classified.
# Epoch 624: 118/120 samples correctly classified.
# Epoch 625: 116/120 samples correctly classified.
# Epoch 626: 117/120 samples correctly classified.
# Epoch 627: 117/120 samples correctly classified.
# Epoch 628: 116/120 samples correctly classified.
# Epoch 629: 115/120 samples correctly classified.
# Epoch 630: 117/120 samples correctly classified.
# Epoch 631: 118/120 samples correctly classified.
# Epoch 632: 118/120 samples correctly classified.
# Epoch 633: 118/120 samples correctly classified.
# Epoch 634: 118/120 samples correctly classified.
# Epoch 635: 118/120 samples correctly classified.
# Epoch 636: 117/120 samples correctly classified.
# Epoch 637: 118/120 samples correctly classified.
# Epoch 638: 116/120 samples correctly classified.
# Epoch 639: 117/120 samples correctly classified.
# Epoch 640: 117/120 samples correctly classified.
# Epoch 641: 118/120 samples correctly classified.
# Epoch 642: 118/120 samples correctly classified.
# Epoch 643: 119/120 samples correctly classified.
# Epoch 644: 117/120 samples correctly classified.
# Epoch 645: 118/120 samples correctly classified.
# Epoch 646: 116/120 samples correctly classified.
# Epoch 647: 116/120 samples correctly classified.
# Epoch 648: 117/120 samples correctly classified.
# Epoch 649: 117/120 samples correctly classified.
# Epoch 650: 118/120 samples correctly classified.
# Epoch 651: 117/120 samples correctly classified.
# Epoch 652: 119/120 samples correctly classified.
# Epoch 653: 118/120 samples correctly classified.
# Epoch 654: 118/120 samples correctly classified.
# Epoch 655: 118/120 samples correctly classified.
# Epoch 656: 117/120 samples correctly classified.
# Epoch 657: 118/120 samples correctly classified.
# Epoch 658: 116/120 samples correctly classified.
# Epoch 659: 117/120 samples correctly classified.
# Epoch 660: 117/120 samples correctly classified.
# Epoch 661: 118/120 samples correctly classified.
# Epoch 662: 118/120 samples correctly classified.
# Epoch 663: 118/120 samples correctly classified.
# Epoch 664: 118/120 samples correctly classified.
# Epoch 665: 119/120 samples correctly classified.
# Epoch 666: 118/120 samples correctly classified.
# Epoch 667: 118/120 samples correctly classified.
# Epoch 668: 118/120 samples correctly classified.
# Epoch 669: 117/120 samples correctly classified.
# Epoch 670: 119/120 samples correctly classified.
# Epoch 671: 118/120 samples correctly classified.
# Epoch 672: 118/120 samples correctly classified.
# Epoch 673: 117/120 samples correctly classified.
# Epoch 674: 117/120 samples correctly classified.
# Epoch 675: 117/120 samples correctly classified.
# Epoch 676: 118/120 samples correctly classified.
# Epoch 677: 118/120 samples correctly classified.
# Epoch 678: 118/120 samples correctly classified.
# Epoch 679: 119/120 samples correctly classified.
# Epoch 680: 117/120 samples correctly classified.
# Epoch 681: 118/120 samples correctly classified.
# Epoch 682: 117/120 samples correctly classified.
# Epoch 683: 117/120 samples correctly classified.
# Epoch 684: 116/120 samples correctly classified.
# Epoch 685: 117/120 samples correctly classified.
# Epoch 686: 117/120 samples correctly classified.
# Epoch 687: 118/120 samples correctly classified.
# Epoch 688: 119/120 samples correctly classified.
# Epoch 689: 117/120 samples correctly classified.
# Epoch 690: 119/120 samples correctly classified.
# Epoch 691: 118/120 samples correctly classified.
# Epoch 692: 118/120 samples correctly classified.
# Epoch 693: 118/120 samples correctly classified.
# Epoch 694: 119/120 samples correctly classified.
# Epoch 695: 116/120 samples correctly classified.
# Epoch 696: 117/120 samples correctly classified.
# Epoch 697: 117/120 samples correctly classified.
# Epoch 698: 118/120 samples correctly classified.
# Epoch 699: 117/120 samples correctly classified.
# Epoch 700: 118/120 samples correctly classified.
# Epoch 701: 116/120 samples correctly classified.
# Epoch 702: 118/120 samples correctly classified.
# Epoch 703: 119/120 samples correctly classified.
# Epoch 704: 117/120 samples correctly classified.
# Epoch 705: 118/120 samples correctly classified.
# Epoch 706: 116/120 samples correctly classified.
# Epoch 707: 119/120 samples correctly classified.
# Epoch 708: 117/120 samples correctly classified.
# Epoch 709: 119/120 samples correctly classified.
# Epoch 710: 118/120 samples correctly classified.
# Epoch 711: 118/120 samples correctly classified.
# Epoch 712: 119/120 samples correctly classified.
# Epoch 713: 117/120 samples correctly classified.
# Epoch 714: 119/120 samples correctly classified.
# Epoch 715: 118/120 samples correctly classified.
# Epoch 716: 118/120 samples correctly classified.
# Epoch 717: 117/120 samples correctly classified.
# Epoch 718: 119/120 samples correctly classified.
# Epoch 719: 118/120 samples correctly classified.
# Epoch 720: 118/120 samples correctly classified.
# Epoch 721: 116/120 samples correctly classified.
# Epoch 722: 119/120 samples correctly classified.
# Epoch 723: 116/120 samples correctly classified.
# Epoch 724: 115/120 samples correctly classified.
# Epoch 725: 116/120 samples correctly classified.
# Epoch 726: 117/120 samples correctly classified.
# Epoch 727: 117/120 samples correctly classified.
# Epoch 728: 118/120 samples correctly classified.
# Epoch 729: 119/120 samples correctly classified.
# Epoch 730: 117/120 samples correctly classified.
# Epoch 731: 119/120 samples correctly classified.
# Epoch 732: 118/120 samples correctly classified.
# Epoch 733: 118/120 samples correctly classified.
# Epoch 734: 118/120 samples correctly classified.
# Epoch 735: 119/120 samples correctly classified.
# Epoch 736: 117/120 samples correctly classified.
# Epoch 737: 119/120 samples correctly classified.
# Epoch 738: 117/120 samples correctly classified.
# Epoch 739: 119/120 samples correctly classified.
# Epoch 740: 118/120 samples correctly classified.
# Epoch 741: 118/120 samples correctly classified.
# Epoch 742: 117/120 samples correctly classified.
# Epoch 743: 119/120 samples correctly classified.
# Epoch 744: 118/120 samples correctly classified.
# Epoch 745: 118/120 samples correctly classified.
# Epoch 746: 117/120 samples correctly classified.
# Epoch 747: 117/120 samples correctly classified.
# Epoch 748: 117/120 samples correctly classified.
# Epoch 749: 119/120 samples correctly classified.
# Epoch 750: 117/120 samples correctly classified.
# Epoch 751: 118/120 samples correctly classified.
# Epoch 752: 117/120 samples correctly classified.
# Epoch 753: 117/120 samples correctly classified.
# Epoch 754: 116/120 samples correctly classified.
# Epoch 755: 118/120 samples correctly classified.
# Epoch 756: 116/120 samples correctly classified.
# Epoch 757: 119/120 samples correctly classified.
# Epoch 758: 118/120 samples correctly classified.
# Epoch 759: 118/120 samples correctly classified.
# Epoch 760: 118/120 samples correctly classified.
# Epoch 761: 118/120 samples correctly classified.
# Epoch 762: 118/120 samples correctly classified.
# Epoch 763: 118/120 samples correctly classified.
# Epoch 764: 119/120 samples correctly classified.
# Epoch 765: 116/120 samples correctly classified.
# Epoch 766: 117/120 samples correctly classified.
# Epoch 767: 117/120 samples correctly classified.
# Epoch 768: 119/120 samples correctly classified.
# Epoch 769: 118/120 samples correctly classified.
# Epoch 770: 118/120 samples correctly classified.
# Epoch 771: 118/120 samples correctly classified.
# Epoch 772: 118/120 samples correctly classified.
# Epoch 773: 119/120 samples correctly classified.
# Epoch 774: 116/120 samples correctly classified.
# Epoch 775: 117/120 samples correctly classified.
# Epoch 776: 117/120 samples correctly classified.
# Epoch 777: 119/120 samples correctly classified.
# Epoch 778: 118/120 samples correctly classified.
# Epoch 779: 118/120 samples correctly classified.
# Epoch 780: 118/120 samples correctly classified.
# Epoch 781: 118/120 samples correctly classified.
# Epoch 782: 119/120 samples correctly classified.
# Epoch 783: 116/120 samples correctly classified.
# Epoch 784: 116/120 samples correctly classified.
# Epoch 785: 117/120 samples correctly classified.
# Epoch 786: 119/120 samples correctly classified.
# Epoch 787: 118/120 samples correctly classified.
# Epoch 788: 118/120 samples correctly classified.
# Epoch 789: 118/120 samples correctly classified.
# Epoch 790: 118/120 samples correctly classified.
# Epoch 791: 118/120 samples correctly classified.
# Epoch 792: 117/120 samples correctly classified.
# Epoch 793: 118/120 samples correctly classified.
# Epoch 794: 117/120 samples correctly classified.
# Epoch 795: 118/120 samples correctly classified.
# Epoch 796: 118/120 samples correctly classified.
# Epoch 797: 118/120 samples correctly classified.
# Epoch 798: 118/120 samples correctly classified.
# Epoch 799: 118/120 samples correctly classified.
# Epoch 800: 119/120 samples correctly classified.
# Epoch 801: 116/120 samples correctly classified.
# Epoch 802: 118/120 samples correctly classified.
# Epoch 803: 117/120 samples correctly classified.
# Epoch 804: 116/120 samples correctly classified.
# Epoch 805: 117/120 samples correctly classified.
# Epoch 806: 119/120 samples correctly classified.
# Epoch 807: 117/120 samples correctly classified.
# Epoch 808: 119/120 samples correctly classified.
# Epoch 809: 119/120 samples correctly classified.
# Epoch 810: 117/120 samples correctly classified.
# Epoch 811: 118/120 samples correctly classified.
# Epoch 812: 117/120 samples correctly classified.
# Epoch 813: 119/120 samples correctly classified.
# Epoch 814: 119/120 samples correctly classified.
# Epoch 815: 117/120 samples correctly classified.
# Epoch 816: 119/120 samples correctly classified.
# Epoch 817: 119/120 samples correctly classified.
# Epoch 818: 116/120 samples correctly classified.
# Epoch 819: 118/120 samples correctly classified.
# Epoch 820: 117/120 samples correctly classified.
# Epoch 821: 119/120 samples correctly classified.
# Epoch 822: 117/120 samples correctly classified.
# Epoch 823: 118/120 samples correctly classified.
# Epoch 824: 117/120 samples correctly classified.
# Epoch 825: 119/120 samples correctly classified.
# Epoch 826: 119/120 samples correctly classified.
# Epoch 827: 117/120 samples correctly classified.
# Epoch 828: 119/120 samples correctly classified.
# Epoch 829: 118/120 samples correctly classified.
# Epoch 830: 118/120 samples correctly classified.
# Epoch 831: 119/120 samples correctly classified.
# Epoch 832: 117/120 samples correctly classified.
# Epoch 833: 119/120 samples correctly classified.
# Epoch 834: 117/120 samples correctly classified.
# Epoch 835: 119/120 samples correctly classified.
# Epoch 836: 117/120 samples correctly classified.
# Epoch 837: 119/120 samples correctly classified.
# Epoch 838: 118/120 samples correctly classified.
# Epoch 839: 117/120 samples correctly classified.
# Epoch 840: 119/120 samples correctly classified.
# Epoch 841: 118/120 samples correctly classified.
# Epoch 842: 118/120 samples correctly classified.
# Epoch 843: 117/120 samples correctly classified.
# Epoch 844: 118/120 samples correctly classified.
# Epoch 845: 117/120 samples correctly classified.
# Epoch 846: 119/120 samples correctly classified.
# Epoch 847: 118/120 samples correctly classified.
# Epoch 848: 119/120 samples correctly classified.
# Epoch 849: 117/120 samples correctly classified.
# Epoch 850: 118/120 samples correctly classified.
# Epoch 851: 117/120 samples correctly classified.
# Epoch 852: 119/120 samples correctly classified.
# Epoch 853: 119/120 samples correctly classified.
# Epoch 854: 117/120 samples correctly classified.
# Epoch 855: 118/120 samples correctly classified.
# Epoch 856: 117/120 samples correctly classified.
# Epoch 857: 119/120 samples correctly classified.
# Epoch 858: 119/120 samples correctly classified.
# Epoch 859: 117/120 samples correctly classified.
# Epoch 860: 119/120 samples correctly classified.
# Epoch 861: 118/120 samples correctly classified.
# Epoch 862: 118/120 samples correctly classified.
# Epoch 863: 119/120 samples correctly classified.
# Epoch 864: 117/120 samples correctly classified.
# Epoch 865: 116/120 samples correctly classified.
# Epoch 866: 117/120 samples correctly classified.
# Epoch 867: 119/120 samples correctly classified.
# Epoch 868: 118/120 samples correctly classified.
# Epoch 869: 118/120 samples correctly classified.
# Epoch 870: 118/120 samples correctly classified.
# Epoch 871: 118/120 samples correctly classified.
# Epoch 872: 119/120 samples correctly classified.
# Epoch 873: 117/120 samples correctly classified.
# Epoch 874: 116/120 samples correctly classified.
# Epoch 875: 116/120 samples correctly classified.
# Epoch 876: 116/120 samples correctly classified.
# Epoch 877: 117/120 samples correctly classified.
# Epoch 878: 119/120 samples correctly classified.
# Epoch 879: 118/120 samples correctly classified.
# Epoch 880: 118/120 samples correctly classified.
# Epoch 881: 119/120 samples correctly classified.
# Epoch 882: 117/120 samples correctly classified.
# Epoch 883: 119/120 samples correctly classified.
# Epoch 884: 118/120 samples correctly classified.
# Epoch 885: 118/120 samples correctly classified.
# Epoch 886: 119/120 samples correctly classified.
# Epoch 887: 117/120 samples correctly classified.
# Epoch 888: 116/120 samples correctly classified.
# Epoch 889: 117/120 samples correctly classified.
# Epoch 890: 119/120 samples correctly classified.
# Epoch 891: 118/120 samples correctly classified.
# Epoch 892: 119/120 samples correctly classified.
# Epoch 893: 117/120 samples correctly classified.
# Epoch 894: 119/120 samples correctly classified.
# Epoch 895: 118/120 samples correctly classified.
# Epoch 896: 118/120 samples correctly classified.
# Epoch 897: 119/120 samples correctly classified.
# Epoch 898: 117/120 samples correctly classified.
# Epoch 899: 117/120 samples correctly classified.
# Epoch 900: 117/120 samples correctly classified.
# Epoch 901: 119/120 samples correctly classified.
# Epoch 902: 119/120 samples correctly classified.
# Epoch 903: 118/120 samples correctly classified.
# Epoch 904: 118/120 samples correctly classified.
# Epoch 905: 118/120 samples correctly classified.
# Epoch 906: 118/120 samples correctly classified.
# Epoch 907: 119/120 samples correctly classified.
# Epoch 908: 117/120 samples correctly classified.
# Epoch 909: 117/120 samples correctly classified.
# Epoch 910: 118/120 samples correctly classified.
# Epoch 911: 119/120 samples correctly classified.
# Epoch 912: 119/120 samples correctly classified.
# Epoch 913: 118/120 samples correctly classified.
# Epoch 914: 117/120 samples correctly classified.
# Epoch 915: 119/120 samples correctly classified.
# Epoch 916: 118/120 samples correctly classified.
# Epoch 917: 118/120 samples correctly classified.
# Epoch 918: 117/120 samples correctly classified.
# Epoch 919: 119/120 samples correctly classified.
# Epoch 920: 118/120 samples correctly classified.
# Epoch 921: 119/120 samples correctly classified.
# Epoch 922: 117/120 samples correctly classified.
# Epoch 923: 118/120 samples correctly classified.
# Epoch 924: 118/120 samples correctly classified.
# Epoch 925: 118/120 samples correctly classified.
# Epoch 926: 118/120 samples correctly classified.
# Epoch 927: 119/120 samples correctly classified.
# Epoch 928: 119/120 samples correctly classified.
# Epoch 929: 118/120 samples correctly classified.
# Epoch 930: 118/120 samples correctly classified.
# Epoch 931: 118/120 samples correctly classified.
# Epoch 932: 119/120 samples correctly classified.
# Epoch 933: 119/120 samples correctly classified.
# Epoch 934: 118/120 samples correctly classified.
# Epoch 935: 118/120 samples correctly classified.
# Epoch 936: 117/120 samples correctly classified.
# Epoch 937: 118/120 samples correctly classified.
# Epoch 938: 119/120 samples correctly classified.
# Epoch 939: 117/120 samples correctly classified.
# Epoch 940: 119/120 samples correctly classified.
# Epoch 941: 119/120 samples correctly classified.
# Epoch 942: 117/120 samples correctly classified.
# Epoch 943: 116/120 samples correctly classified.
# Epoch 944: 117/120 samples correctly classified.
# Epoch 945: 119/120 samples correctly classified.
# Epoch 946: 119/120 samples correctly classified.
# Epoch 947: 117/120 samples correctly classified.
# Epoch 948: 119/120 samples correctly classified.
# Epoch 949: 119/120 samples correctly classified.
# Epoch 950: 118/120 samples correctly classified.
# Epoch 951: 118/120 samples correctly classified.
# Epoch 952: 117/120 samples correctly classified.
# Epoch 953: 118/120 samples correctly classified.
# Epoch 954: 118/120 samples correctly classified.
# Epoch 955: 119/120 samples correctly classified.
# Epoch 956: 119/120 samples correctly classified.
# Epoch 957: 117/120 samples correctly classified.
# Epoch 958: 119/120 samples correctly classified.
# Epoch 959: 119/120 samples correctly classified.
# Epoch 960: 118/120 samples correctly classified.
# Epoch 961: 118/120 samples correctly classified.
# Epoch 962: 118/120 samples correctly classified.
# Epoch 963: 119/120 samples correctly classified.
# Epoch 964: 119/120 samples correctly classified.
# Epoch 965: 118/120 samples correctly classified.
# Epoch 966: 118/120 samples correctly classified.
# Epoch 967: 117/120 samples correctly classified.
# Epoch 968: 119/120 samples correctly classified.
# Epoch 969: 119/120 samples correctly classified.
# Epoch 970: 119/120 samples correctly classified.
# Epoch 971: 118/120 samples correctly classified.
# Epoch 972: 118/120 samples correctly classified.
# Epoch 973: 118/120 samples correctly classified.
# Epoch 974: 119/120 samples correctly classified.
# Epoch 975: 119/120 samples correctly classified.
# Epoch 976: 118/120 samples correctly classified.
# Epoch 977: 118/120 samples correctly classified.
# Epoch 978: 118/120 samples correctly classified.
# Epoch 979: 119/120 samples correctly classified.
# Epoch 980: 119/120 samples correctly classified.
# Epoch 981: 118/120 samples correctly classified.
# Epoch 982: 118/120 samples correctly classified.
# Epoch 983: 117/120 samples correctly classified.
# Epoch 984: 118/120 samples correctly classified.
# Epoch 985: 119/120 samples correctly classified.
# Epoch 986: 118/120 samples correctly classified.
# Epoch 987: 118/120 samples correctly classified.
# Epoch 988: 118/120 samples correctly classified.
# Epoch 989: 118/120 samples correctly classified.
# Epoch 990: 119/120 samples correctly classified.
# Epoch 991: 117/120 samples correctly classified.
# Epoch 992: 118/120 samples correctly classified.
# Epoch 993: 118/120 samples correctly classified.
# Epoch 994: 119/120 samples correctly classified.
# Epoch 995: 119/120 samples correctly classified.
# Epoch 996: 119/120 samples correctly classified.
# Epoch 997: 117/120 samples correctly classified.
# Epoch 998: 118/120 samples correctly classified.
# Epoch 999: 118/120 samples correctly classified.
# Epoch 1000: 119/120 samples correctly classified.
# Epoch 1001: 119/120 samples correctly classified.
# Epoch 1002: 119/120 samples correctly classified.
# Epoch 1003: 117/120 samples correctly classified.
# Epoch 1004: 118/120 samples correctly classified.
# Epoch 1005: 117/120 samples correctly classified.
# Epoch 1006: 119/120 samples correctly classified.
# Epoch 1007: 119/120 samples correctly classified.
# Epoch 1008: 118/120 samples correctly classified.
# Epoch 1009: 119/120 samples correctly classified.
# Epoch 1010: 119/120 samples correctly classified.
# Epoch 1011: 119/120 samples correctly classified.
# Epoch 1012: 119/120 samples correctly classified.
# Epoch 1013: 119/120 samples correctly classified.
# Epoch 1014: 119/120 samples correctly classified.
# Epoch 1015: 118/120 samples correctly classified.
# Epoch 1016: 118/120 samples correctly classified.
# Epoch 1017: 117/120 samples correctly classified.
# Epoch 1018: 118/120 samples correctly classified.
# Epoch 1019: 119/120 samples correctly classified.
# Epoch 1020: 118/120 samples correctly classified.
# Epoch 1021: 119/120 samples correctly classified.
# Epoch 1022: 119/120 samples correctly classified.
# Epoch 1023: 119/120 samples correctly classified.
# Epoch 1024: 119/120 samples correctly classified.
# Epoch 1025: 120/120 samples correctly classified.
# Converged at epoch 1025
# Best accuracy: 100.00%
# Best weights:
# [[ 0.10778088  0.38794006  0.17255733 -0.2131355  -0.00071594  0.02717306
#    0.03179535 -0.05445541 -0.054     ]
#  [ 0.47918295  0.2616198  -0.0826106   0.04277283  0.09819543 -0.02821075
#   -0.03847355  0.01736409  0.127     ]
#  [ 0.61303617  0.15044014  0.11005327  0.17036267 -0.09747948  0.00103769
#    0.0066782   0.03709132 -0.073     ]]
